# %%
import pandas as pd,numpy as np,re

import warnings
warnings.filterwarnings("ignore")

# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
data1_final = pd.read_csv("data1_final.csv")
data2_final = pd.read_csv("data2_final.csv")
data3_final = pd.read_csv("data3_final.csv")

# %%
data1_clean = data1_final.drop(["id"],axis = 1)
data1_clean
# Out:
#                                  name                  common_name sex_filter  \
# 0                    Abdominal injury      Recent abdominal injury       both
# 1         Absent COVID-19 vaccination  Absent COVID-19 vaccination       both
# 2    Acceleration-deceleration injury              Whiplash injury       both
# 3                         Animal bite                  Animal bite       both
# 4                        Ankle injury                 Ankle injury       both
# ..                                ...                          ...        ...
# 172                 Upper limb injury            Upper limb injury       both
# 173               Weather sensitivity   Weather change sensitivity       both
# 174         Wild mushroom consumption    Wild mushroom consumption       both
# 175                             Woman                        Woman       both
# 176                      Wrist injury                 Wrist injury       both
#
#          category seriousness
# 0    Risk factors      normal
# 1    Risk factors      normal
# 2    Risk factors     serious
# 3    Risk factors     serious
# 4    Risk factors      normal
# ..            ...         ...
# 172  Risk factors      normal
# 173  Risk factors      normal
# 174  Risk factors      normal
# 175  Risk factors      normal
# 176  Risk factors      normal
#
# [177 rows x 5 columns]

# %%
data1_final['common_name'][8]
# Out:
# 'Activities related to sudden pressure or altitude changes'

# %%
data3_final.head()
# Out:
#       id                         name                  common_name sex_filter  \
# 0  c_926  ACE inhibitor-induced cough  ACE inhibitor-induced cough       both
# 1  c_764    Abdominal aortic aneurysm    Abdominal aortic aneurysm       both
# 2  c_885  Abdominal aortic dissection  Abdominal aortic dissection       both
# 3  c_969  Abdominal pain, unspecified    Unspecific abdominal pain       both
# 4  c_547         Abducens nerve palsy            Sixth nerve palsy       both
#
#              categories prevalence                  acuteness severity  \
# 0        ['Cardiology']  very_rare  acute_potentially_chronic     mild
# 1           ['Surgery']  very_rare                    chronic   severe
# 2           ['Surgery']  very_rare  acute_potentially_chronic   severe
# 3  ['Gastroenterology']     common                      acute     mild
# 4     ['Ophthalmology']  very_rare                    chronic     mild
#
#           triage_level     recommended_channel
# 0         consultation  audio_teleconsultation
# 1      consultation_24          personal_visit
# 2  emergency_ambulance          personal_visit
# 3            self_care   text_teleconsultation
# 4         consultation          personal_visit

# %%
data1_final.category.unique()
# Out:
# array(['Risk factors'], dtype=object)

# %%
#unique data  
for x in data1_final.columns[-3:]:
    print(f"{x} = {data1_final[x].unique()}")
# Out:
# sex_filter = ['both' 'female' 'male']
# category = ['Risk factors']
# seriousness = ['normal' 'serious' 'emergency_ambulance' 'emergency']

# %% [markdown]
# ---

# %%
data2_final.set_index('id',inplace = True)
data2_final.head()
# Out:
#                                       name                      common_name  \
# id
# s_1558                  Abdominal guarding               Abdominal guarding
# s_299                       Abdominal mass                  Lump in stomach
# s_13                        Abdominal pain                     Stomach pain
# s_1598  Abdominal pain, below belly button               Lower stomach pain
# s_1802  Abdominal pain, burning or gnawing  Burning or gnawing stomach pain
#
#        sex_filter            category seriousness
# id
# s_1558       both  Signs and symptoms   emergency
# s_299        both  Signs and symptoms      normal
# s_13         both  Signs and symptoms      normal
# s_1598       both  Signs and symptoms      normal
# s_1802       both  Signs and symptoms      normal

# %%
#unique data  
for x in data2_final.columns[-3:]:
    print(f"{x} = {data2_final[x].unique()}")
# Out:
# sex_filter = ['both' 'female' 'male']
# category = ['Signs and symptoms' 'Other']
# seriousness = ['emergency' 'normal' 'serious' 'emergency_ambulance']

# %%
data2_name = data2_final['name'].str.split(",",expand=True)
data2_name.head()
# Out:
#                          0                    1     2     3
# id
# s_1558  Abdominal guarding                 None  None  None
# s_299       Abdominal mass                 None  None  None
# s_13        Abdominal pain                 None  None  None
# s_1598      Abdominal pain   below belly button  None  None
# s_1802      Abdominal pain   burning or gnawing  None  None

# %%
data2_name.fillna('',inplace = True)
data2_name.sample(20)
# Out:
#                                            0                                1  \
# id
# s_336                               Jaundice        during infectious disease
# s_2471                 Loss of consciousness   in a sitting or lying position
# s_31                              Chest pain           continuing during rest
# s_2375               Blood oxygen saturation                     not measured
# s_1186                                 Fever         flare-ups and remissions
# s_1408              Local retinal undulation
# s_579                     Pain in lower limb
# s_588                      Alcohol tolerance
# s_38                               Back pain                           lumbar
# s_2059                Dermatological changes                            scalp
# s_1056                  Trigeminal neuralgia
# s_1154     Difficulty completely closing eye
# s_1393                    Painful defecation
# s_1810                Dermatological changes      located in the genital area
# s_730                 Diurnal mood variation
# s_1693  Decreased intensity of breath sounds
# s_1228                 Convergent strabismus
# s_1090                           Glassy eyes
# s_2303                 Loss of consciousness               more than 1 minute
# s_1562                              Wheezing                          stridor
#
#                                      2 3
# id
# s_336
# s_2471
# s_31
# s_2375
# s_1186
# s_1408
# s_579
# s_588
# s_38     radiates to back of the thigh
# s_2059
# s_1056
# s_1154
# s_1393
# s_1810
# s_730
# s_1693
# s_1228
# s_1090
# s_2303
# s_1562

# %%
data2_name[3].unique()
# Out:
# array(['', ' or cosmetics', ' or shape', ' or physical exercises',
#        ' or wearing wool', ' new neurological problem'], dtype=object)

# %%
data2_name.columns = ['name','disease_specify1','disease_specify2','disease_specify3']
data2_name.head()
# Out:
#                       name     disease_specify1 disease_specify2  \
# id
# s_1558  Abdominal guarding
# s_299       Abdominal mass
# s_13        Abdominal pain
# s_1598      Abdominal pain   below belly button
# s_1802      Abdominal pain   burning or gnawing
#
#        disease_specify3
# id
# s_1558
# s_299
# s_13
# s_1598
# s_1802

# %%
data2_clean = data2_final.merge(data2_name,how='left',on='id')
data2_clean.head()
# Out:
#                                     name_x                      common_name  \
# id
# s_1558                  Abdominal guarding               Abdominal guarding
# s_299                       Abdominal mass                  Lump in stomach
# s_13                        Abdominal pain                     Stomach pain
# s_1598  Abdominal pain, below belly button               Lower stomach pain
# s_1802  Abdominal pain, burning or gnawing  Burning or gnawing stomach pain
#
#        sex_filter            category seriousness              name_y  \
# id
# s_1558       both  Signs and symptoms   emergency  Abdominal guarding
# s_299        both  Signs and symptoms      normal      Abdominal mass
# s_13         both  Signs and symptoms      normal      Abdominal pain
# s_1598       both  Signs and symptoms      normal      Abdominal pain
# s_1802       both  Signs and symptoms      normal      Abdominal pain
#
#            disease_specify1 disease_specify2 disease_specify3
# id
# s_1558
# s_299
# s_13
# s_1598   below belly button
# s_1802   burning or gnawing

# %%
data2_clean.drop('name_x',axis=1,inplace=True)

# %%
data2_clean.rename(columns = {"name_y": "name"}, 
          inplace = True)

# %%
data2_clean.columns
# Out:
# Index(['common_name', 'sex_filter', 'category', 'seriousness', 'name',
#        'disease_specify1', 'disease_specify2', 'disease_specify3'],
#       dtype='object')

# %%
data2_clean = data2_clean.reindex(columns=['name','disease_specify1', 'disease_specify2', 'disease_specify3','common_name', 'sex_filter', 'category', 'seriousness'])

# %%
data2_clean.head()
# Out:
#                       name     disease_specify1 disease_specify2  \
# id
# s_1558  Abdominal guarding
# s_299       Abdominal mass
# s_13        Abdominal pain
# s_1598      Abdominal pain   below belly button
# s_1802      Abdominal pain   burning or gnawing
#
#        disease_specify3                      common_name sex_filter  \
# id
# s_1558                                Abdominal guarding       both
# s_299                                    Lump in stomach       both
# s_13                                        Stomach pain       both
# s_1598                                Lower stomach pain       both
# s_1802                   Burning or gnawing stomach pain       both
#
#                   category seriousness
# id
# s_1558  Signs and symptoms   emergency
# s_299   Signs and symptoms      normal
# s_13    Signs and symptoms      normal
# s_1598  Signs and symptoms      normal
# s_1802  Signs and symptoms      normal

# %% [markdown]
# ---

# %%
data3_final.set_index('id',inplace = True)
data3_final.head()
# Out:
#                               name                  common_name sex_filter  \
# id
# c_926  ACE inhibitor-induced cough  ACE inhibitor-induced cough       both
# c_764    Abdominal aortic aneurysm    Abdominal aortic aneurysm       both
# c_885  Abdominal aortic dissection  Abdominal aortic dissection       both
# c_969  Abdominal pain, unspecified    Unspecific abdominal pain       both
# c_547         Abducens nerve palsy            Sixth nerve palsy       both
#
#                  categories prevalence                  acuteness severity  \
# id
# c_926        ['Cardiology']  very_rare  acute_potentially_chronic     mild
# c_764           ['Surgery']  very_rare                    chronic   severe
# c_885           ['Surgery']  very_rare  acute_potentially_chronic   severe
# c_969  ['Gastroenterology']     common                      acute     mild
# c_547     ['Ophthalmology']  very_rare                    chronic     mild
#
#               triage_level     recommended_channel
# id
# c_926         consultation  audio_teleconsultation
# c_764      consultation_24          personal_visit
# c_885  emergency_ambulance          personal_visit
# c_969            self_care   text_teleconsultation
# c_547         consultation          personal_visit

# %%
trim = "[']"
for x in trim:
    data3_final['categories'] = data3_final['categories'].str.replace(x,"")
data3_final['categories']
# Out:
# id
# c_926           Cardiology
# c_764              Surgery
# c_885              Surgery
# c_969     Gastroenterology
# c_547        Ophthalmology
#                 ...
# c_1043        Traumatology
# c_1027        Traumatology
# c_244         Infectiology
# c_906         Infectiology
# c_213     Gastroenterology
# Name: categories, Length: 709, dtype: object

# %%
data3_final.head()
# Out:
#                               name                  common_name sex_filter  \
# id
# c_926  ACE inhibitor-induced cough  ACE inhibitor-induced cough       both
# c_764    Abdominal aortic aneurysm    Abdominal aortic aneurysm       both
# c_885  Abdominal aortic dissection  Abdominal aortic dissection       both
# c_969  Abdominal pain, unspecified    Unspecific abdominal pain       both
# c_547         Abducens nerve palsy            Sixth nerve palsy       both
#
#              categories prevalence                  acuteness severity  \
# id
# c_926        Cardiology  very_rare  acute_potentially_chronic     mild
# c_764           Surgery  very_rare                    chronic   severe
# c_885           Surgery  very_rare  acute_potentially_chronic   severe
# c_969  Gastroenterology     common                      acute     mild
# c_547     Ophthalmology  very_rare                    chronic     mild
#
#               triage_level     recommended_channel
# id
# c_926         consultation  audio_teleconsultation
# c_764      consultation_24          personal_visit
# c_885  emergency_ambulance          personal_visit
# c_969            self_care   text_teleconsultation
# c_547         consultation          personal_visit

# %%
#unique data  
for x in data3_final.columns[2:]:
    print(f"{x} = {data3_final[x].unique()}")
# Out:
# sex_filter = ['both' 'female' 'male']
# categories = ['Cardiology' 'Surgery' 'Gastroenterology' 'Ophthalmology' 'Toxicology'
#  'Orthopedics' 'Traumatology' 'Dermatology' 'Infectiology' 'Endocrinology'
#  'Otorhinolaryngology' 'Pulmonology' 'Urology' 'Nephrology' 'Hematology'
#  'Genetics' 'Psychiatry' 'Gynecology' 'Oncology' 'Allergology'
#  'Rheumatology' 'Neurology' 'Venereology' 'Dentistry' 'Other'
#  'Internal Medicine' 'Angiology' 'Diabetology' 'Pediatrics']
# prevalence = ['very_rare' 'common' 'moderate' 'rare']
# acuteness = ['acute_potentially_chronic' 'chronic' 'acute'
#  'chronic_with_exacerbations']
# severity = ['mild' 'severe' 'moderate']
# triage_level = ['consultation' 'consultation_24' 'emergency_ambulance' 'self_care'
#  'emergency']
# recommended_channel = ['audio_teleconsultation' 'personal_visit' 'text_teleconsultation'
#  'video_teleconsultation']

# %%
data3_clean = data3_final
data3_clean.head()
# Out:
#                               name                  common_name sex_filter  \
# id
# c_926  ACE inhibitor-induced cough  ACE inhibitor-induced cough       both
# c_764    Abdominal aortic aneurysm    Abdominal aortic aneurysm       both
# c_885  Abdominal aortic dissection  Abdominal aortic dissection       both
# c_969  Abdominal pain, unspecified    Unspecific abdominal pain       both
# c_547         Abducens nerve palsy            Sixth nerve palsy       both
#
#              categories prevalence                  acuteness severity  \
# id
# c_926        Cardiology  very_rare  acute_potentially_chronic     mild
# c_764           Surgery  very_rare                    chronic   severe
# c_885           Surgery  very_rare  acute_potentially_chronic   severe
# c_969  Gastroenterology     common                      acute     mild
# c_547     Ophthalmology  very_rare                    chronic     mild
#
#               triage_level     recommended_channel
# id
# c_926         consultation  audio_teleconsultation
# c_764      consultation_24          personal_visit
# c_885  emergency_ambulance          personal_visit
# c_969            self_care   text_teleconsultation
# c_547         consultation          personal_visit

# %% [markdown]
# ---

# %%
data1_group = data1_clean.groupby(['name','common_name']).first()
data2_group = data2_clean.groupby(['name','common_name']).first()
data3_group = data3_clean.groupby(['name','common_name']).first()

# %%
data1_group.shape[0] == data1_clean.shape[0],data2_group.shape[0] == data2_clean.shape[0],data3_group.shape[0] == data3_clean.shape[0]
# Out:
# (True, True, True)

# %%
#finding the disease
def pattern (df,find):
    temp_df = df[df.apply(lambda row: row.astype(str).str.contains(find,case=False).any(), axis=1)]
    def color_negative_red(value):
        val = value.lower()
        color = 'yellow' if re.findall(find,val) else ''
        return 'background-color: %s'% color

    return temp_df.style.applymap(color_negative_red)

pattern(data2_clean,'fever')
# Out:
# <style type="text/css">
# #T_ff9dd_row0_col0, #T_ff9dd_row0_col4, #T_ff9dd_row1_col0, #T_ff9dd_row1_col4, #T_ff9dd_row2_col0, #T_ff9dd_row3_col0, #T_ff9dd_row3_col4, #T_ff9dd_row4_col0, #T_ff9dd_row4_col4, #T_ff9dd_row5_col0, #T_ff9dd_row5_col4, #T_ff9dd_row6_col0, #T_ff9dd_row6_col4, #T_ff9dd_row7_col0, #T_ff9dd_row7_col4, #T_ff9dd_row8_col0, #T_ff9dd_row8_col4, #T_ff9dd_row9_col0, #T_ff9dd_row9_col4, #T_ff9dd_row10_col0, #T_ff9dd_row10_col4 {
#   background-color: yellow;
# }
# #T_ff9dd_row0_col1, #T_ff9dd_row0_col2, #T_ff9dd_row0_col3, #T_ff9dd_row0_col5, #T_ff9dd_row0_col6, #T_ff9dd_row0_col7, #T_ff9dd_row1_col1, #T_ff9dd_row1_col2, #T_ff9dd_row1_col3, #T_ff9dd_row1_col5, #T_ff9dd_row1_col6, #T_ff9dd_row1_col7, #T_ff9dd_row2_col1, #T_ff9dd_row2_col2, #T_ff9dd_row2_col3, #T_ff9dd_row2_col4, #T_ff9dd_row2_col5, #T_ff9dd_row2_col6, #T_ff9dd_row2_col7, #T_ff9dd_row3_col1, #T_ff9dd_row3_col2, #T_ff9dd_row3_col3, #T_ff9dd_row3_col5, #T_ff9dd_row3_col6, #T_ff9dd_row3_col7, #T_ff9dd_row4_col1, #T_ff9dd_row4_col2, #T_ff9dd_row4_col3, #T_ff9dd_row4_col5, #T_ff9dd_row4_col6, #T_ff9dd_row4_col7, #T_ff9dd_row5_col1, #T_ff9dd_row5_col2, #T_ff9dd_row5_col3, #T_ff9dd_row5_col5, #T_ff9dd_row5_col6, #T_ff9dd_row5_col7, #T_ff9dd_row6_col1, #T_ff9dd_row6_col2, #T_ff9dd_row6_col3, #T_ff9dd_row6_col5, #T_ff9dd_row6_col6, #T_ff9dd_row6_col7, #T_ff9dd_row7_col1, #T_ff9dd_row7_col2, #T_ff9dd_row7_col3, #T_ff9dd_row7_col5, #T_ff9dd_row7_col6, #T_ff9dd_row7_col7, #T_ff9dd_row8_col1, #T_ff9dd_row8_col2, #T_ff9dd_row8_col3, #T_ff9dd_row8_col5, #T_ff9dd_row8_col6, #T_ff9dd_row8_col7, #T_ff9dd_row9_col1, #T_ff9dd_row9_col2, #T_ff9dd_row9_col3, #T_ff9dd_row9_col5, #T_ff9dd_row9_col6, #T_ff9dd_row9_col7, #T_ff9dd_row10_col1, #T_ff9dd_row10_col2, #T_ff9dd_row10_col3, #T_ff9dd_row10_col5, #T_ff9dd_row10_col6, #T_ff9dd_row10_col7 {
#   background-color: ;
# }
# </style>
# <table id="T_ff9dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff9dd_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_ff9dd_level0_col1" class="col_heading level0 col1" >disease_specify1</th>
#       <th id="T_ff9dd_level0_col2" class="col_heading level0 col2" >disease_specify2</th>
#       <th id="T_ff9dd_level0_col3" class="col_heading level0 col3" >disease_specify3</th>
#       <th id="T_ff9dd_level0_col4" class="col_heading level0 col4" >common_name</th>
#       <th id="T_ff9dd_level0_col5" class="col_heading level0 col5" >sex_filter</th>
#       <th id="T_ff9dd_level0_col6" class="col_heading level0 col6" >category</th>
#       <th id="T_ff9dd_level0_col7" class="col_heading level0 col7" >seriousness</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff9dd_level0_row0" class="row_heading level0 row0" >s_98</th>
#       <td id="T_ff9dd_row0_col0" class="data row0 col0" >Fever</td>
#       <td id="T_ff9dd_row0_col1" class="data row0 col1" ></td>
#       <td id="T_ff9dd_row0_col2" class="data row0 col2" ></td>
#       <td id="T_ff9dd_row0_col3" class="data row0 col3" ></td>
#       <td id="T_ff9dd_row0_col4" class="data row0 col4" >Fever</td>
#       <td id="T_ff9dd_row0_col5" class="data row0 col5" >both</td>
#       <td id="T_ff9dd_row0_col6" class="data row0 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row0_col7" class="data row0 col7" >normal</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row1" class="row_heading level0 row1" >s_100</th>
#       <td id="T_ff9dd_row1_col0" class="data row1 col0" >Fever</td>
#       <td id="T_ff9dd_row1_col1" class="data row1 col1" > between 100.4 and 104°F or 38 and 40°C</td>
#       <td id="T_ff9dd_row1_col2" class="data row1 col2" ></td>
#       <td id="T_ff9dd_row1_col3" class="data row1 col3" ></td>
#       <td id="T_ff9dd_row1_col4" class="data row1 col4" >Fever between 100.4 and 104°F or 38 and 40°C</td>
#       <td id="T_ff9dd_row1_col5" class="data row1 col5" >both</td>
#       <td id="T_ff9dd_row1_col6" class="data row1 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row1_col7" class="data row1 col7" >normal</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row2" class="row_heading level0 row2" >s_99</th>
#       <td id="T_ff9dd_row2_col0" class="data row2 col0" >Fever</td>
#       <td id="T_ff9dd_row2_col1" class="data row2 col1" > between 98.6 and 100.4°F or 37 and 38°C</td>
#       <td id="T_ff9dd_row2_col2" class="data row2 col2" ></td>
#       <td id="T_ff9dd_row2_col3" class="data row2 col3" ></td>
#       <td id="T_ff9dd_row2_col4" class="data row2 col4" >Subfebrile temperature between 98.6 and 100.4°F or 37 and 38°C</td>
#       <td id="T_ff9dd_row2_col5" class="data row2 col5" >both</td>
#       <td id="T_ff9dd_row2_col6" class="data row2 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row2_col7" class="data row2 col7" >normal</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row3" class="row_heading level0 row3" >s_1186</th>
#       <td id="T_ff9dd_row3_col0" class="data row3 col0" >Fever</td>
#       <td id="T_ff9dd_row3_col1" class="data row3 col1" > flare-ups and remissions</td>
#       <td id="T_ff9dd_row3_col2" class="data row3 col2" ></td>
#       <td id="T_ff9dd_row3_col3" class="data row3 col3" ></td>
#       <td id="T_ff9dd_row3_col4" class="data row3 col4" >Fever that comes and goes</td>
#       <td id="T_ff9dd_row3_col5" class="data row3 col5" >both</td>
#       <td id="T_ff9dd_row3_col6" class="data row3 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row3_col7" class="data row3 col7" >normal</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row4" class="row_heading level0 row4" >s_2000</th>
#       <td id="T_ff9dd_row4_col0" class="data row4 col0" >Fever</td>
#       <td id="T_ff9dd_row4_col1" class="data row4 col1" > higher than 104°F or 40°C</td>
#       <td id="T_ff9dd_row4_col2" class="data row4 col2" ></td>
#       <td id="T_ff9dd_row4_col3" class="data row4 col3" ></td>
#       <td id="T_ff9dd_row4_col4" class="data row4 col4" >Fever higher than 104°F or 40°C</td>
#       <td id="T_ff9dd_row4_col5" class="data row4 col5" >both</td>
#       <td id="T_ff9dd_row4_col6" class="data row4 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row4_col7" class="data row4 col7" >serious</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row5" class="row_heading level0 row5" >s_2320</th>
#       <td id="T_ff9dd_row5_col0" class="data row5 col0" >Fever</td>
#       <td id="T_ff9dd_row5_col1" class="data row5 col1" > lasting 3 to 7 days</td>
#       <td id="T_ff9dd_row5_col2" class="data row5 col2" ></td>
#       <td id="T_ff9dd_row5_col3" class="data row5 col3" ></td>
#       <td id="T_ff9dd_row5_col4" class="data row5 col4" >Fever lasting 3 to 7 days</td>
#       <td id="T_ff9dd_row5_col5" class="data row5 col5" >both</td>
#       <td id="T_ff9dd_row5_col6" class="data row5 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row5_col7" class="data row5 col7" >normal</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row6" class="row_heading level0 row6" >s_2319</th>
#       <td id="T_ff9dd_row6_col0" class="data row6 col0" >Fever</td>
#       <td id="T_ff9dd_row6_col1" class="data row6 col1" > lasting less than 3 days</td>
#       <td id="T_ff9dd_row6_col2" class="data row6 col2" ></td>
#       <td id="T_ff9dd_row6_col3" class="data row6 col3" ></td>
#       <td id="T_ff9dd_row6_col4" class="data row6 col4" >Fever lasting less than 3 days</td>
#       <td id="T_ff9dd_row6_col5" class="data row6 col5" >both</td>
#       <td id="T_ff9dd_row6_col6" class="data row6 col6" >Signs and symptoms</td>
#       <td id="T_ff9dd_row6_col7" class="data row6 col7" >normal</td>
#     </tr>
#     <tr>
#       <th id="T_ff9dd_level0_row7" class="row_heading level0 row7" >s_2321</th>
#       <td

# %%
data1_group.to_csv("data1_group_mf.csv")

# %%
data2_group.reset_index().to_csv("data2_group_mf.csv",index=False)

# %%
data3_group.to_csv("data3_group_mf.csv")

# %%
data2_group.head()
# Out:
#                                                               disease_specify1  \
# name               common_name
# Abdominal guarding Abdominal guarding
# Abdominal mass     Lump in stomach
# Abdominal pain     Abdominal pain, unspecified location   unspecified location
#                    Burning or gnawing stomach pain          burning or gnawing
#                    Central stomach pain                          periumbilical
#
#                                                         disease_specify2  \
# name               common_name
# Abdominal guarding Abdominal guarding
# Abdominal mass     Lump in stomach
# Abdominal pain     Abdominal pain, unspecified location
#                    Burning or gnawing stomach pain
#                    Central stomach pain
#
#                                                         disease_specify3  \
# name               common_name
# Abdominal guarding Abdominal guarding
# Abdominal mass     Lump in stomach
# Abdominal pain     Abdominal pain, unspecified location
#                    Burning or gnawing stomach pain
#                    Central stomach pain
#
#                                                         sex_filter  \
# name               common_name
# Abdominal guarding Abdominal guarding                         both
# Abdominal mass     Lump in stomach                            both
# Abdominal pain     Abdominal pain, unspecified location       both
#                    Burning or gnawing stomach pain            both
#                    Central stomach pain                       both
#
#                                                                    category  \
# name               common_name
# Abdominal guarding Abdominal guarding                    Signs and symptoms
# Abdominal mass     Lump in stomach                       Signs and symptoms
# Abdominal pain     Abdominal pain, unspecified location  Signs and symptoms
#                    Burning or gnawing stomach pain       Signs and symptoms
#                    Central stomach pain                  Signs and symptoms
#
#                                                         seriousness
# name               common_name
# Abdominal guarding Abdominal guarding                     emergency
# Abdominal mass     Lump in stomach                           normal
# Abdominal pain     Abdominal pain, unspecified location      normal
#                    Burning or gnawing stomach pain           normal
#                    Central stomach pain                      normal

# %%
data3_group.head()
# Out:
#                                                         sex_filter  \
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough       both
# Abdominal aortic aneurysm   Abdominal aortic aneurysm         both
# Abdominal aortic dissection Abdominal aortic dissection       both
# Abdominal pain, unspecified Unspecific abdominal pain         both
# Abducens nerve palsy        Sixth nerve palsy                 both
#
#                                                                categories  \
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough        Cardiology
# Abdominal aortic aneurysm   Abdominal aortic aneurysm             Surgery
# Abdominal aortic dissection Abdominal aortic dissection           Surgery
# Abdominal pain, unspecified Unspecific abdominal pain    Gastroenterology
# Abducens nerve palsy        Sixth nerve palsy               Ophthalmology
#
#                                                         prevalence  \
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough  very_rare
# Abdominal aortic aneurysm   Abdominal aortic aneurysm    very_rare
# Abdominal aortic dissection Abdominal aortic dissection  very_rare
# Abdominal pain, unspecified Unspecific abdominal pain       common
# Abducens nerve palsy        Sixth nerve palsy            very_rare
#
#                                                                          acuteness  \
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough  acute_potentially_chronic
# Abdominal aortic aneurysm   Abdominal aortic aneurysm                      chronic
# Abdominal aortic dissection Abdominal aortic dissection  acute_potentially_chronic
# Abdominal pain, unspecified Unspecific abdominal pain                        acute
# Abducens nerve palsy        Sixth nerve palsy                              chronic
#
#                                                         severity  \
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough     mild
# Abdominal aortic aneurysm   Abdominal aortic aneurysm     severe
# Abdominal aortic dissection Abdominal aortic dissection   severe
# Abdominal pain, unspecified Unspecific abdominal pain       mild
# Abducens nerve palsy        Sixth nerve palsy               mild
#
#                                                                 triage_level  \
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough         consultation
# Abdominal aortic aneurysm   Abdominal aortic aneurysm        consultation_24
# Abdominal aortic dissection Abdominal aortic dissection  emergency_ambulance
# Abdominal pain, unspecified Unspecific abdominal pain              self_care
# Abducens nerve palsy        Sixth nerve palsy                   consultation
#
#                                                             recommended_channel
# name                        common_name
# ACE inhibitor-induced cough ACE inhibitor-induced cough  audio_teleconsultation
# Abdominal aortic aneurysm   Abdominal aortic aneurysm            personal_visit
# Abdominal aortic dissection Abdominal aortic dissection          personal_visit
# Abdominal pain, unspecified Unspecific abdominal pain     text_teleconsultation
# Abducens nerve palsy        Sixth nerve palsy                    personal_visit
