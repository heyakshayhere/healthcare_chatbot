# %%
import pandas as pd,numpy as np,re

import warnings
warnings.filterwarnings("ignore")

# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
data1_group_mm = pd.read_csv("data1_group_mm.csv")
data1_group_mf = pd.read_csv("data1_group_mf.csv")
data3_group_mm = pd.read_csv("data3_group_mm.csv")
data3_group_mf = pd.read_csv("data3_group_mf.csv")
data2_group_mf = pd.read_csv("data2_group_mf.csv")

# %%
class df_options:
    def __init__ (self,df1,df2):
        self.df1 = df1
        self.df2 = df2
    
    def merged_data(self):
        data_merged = pd.merge(self.df1, self.df2,how="outer")
        return data_merged
    
    def uncomman_data(self):
        uncomman_data = self.df1.merge(self.df2, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']
        return uncomman_data
    
    @staticmethod
    def pattern (df,find):
        temp_df = df[df.apply(lambda row: row.astype(str).str.contains(find,case=False).any(), axis=1)]
        def color_negative_red(val):
            color = 'yellow' if re.search(find,val,flags = re.IGNORECASE) else ''
            return 'background-color: %s'% color

        return temp_df.style.applymap(color_negative_red)

# %% [markdown]
# ----

# %%
obj1 = df_options(data1_group_mm,data1_group_mf)
data1 = obj1.merged_data()
data1.head()
# Out:
#                                name                  common_name sex_filter  \
# 0                  Abdominal injury      Recent abdominal injury       both
# 1       Absent COVID-19 vaccination  Absent COVID-19 vaccination       both
# 2  Acceleration-deceleration injury              Whiplash injury       both
# 3                       Animal bite                  Animal bite       both
# 4                      Ankle injury                 Ankle injury       both
#
#        category seriousness
# 0  Risk factors      normal
# 1  Risk factors      normal
# 2  Risk factors     serious
# 3  Risk factors     serious
# 4  Risk factors      normal

# %%
obj1.uncomman_data()
# Out:
#                                       name  \
# 34           Diagnosed atrial fibrillation
# 37              Diagnosed coronary disease
# 45    Diagnosed osteoporosis or osteopenia
# 46   Diagnosed peripheral vascular disease
# 75         History of deep vein thrombosis
# 79         History of heart bypass surgery
# 98                       History of stroke
# 141            Prior myocardial infarction
#
#                                common_name sex_filter      category  \
# 34           Diagnosed atrial fibrillation       both  Risk factors
# 37              Diagnosed coronary disease       both  Risk factors
# 45    Diagnosed osteoporosis or osteopenia       both  Risk factors
# 46   Diagnosed peripheral vascular disease       both  Risk factors
# 75         History of deep vein thrombosis       both  Risk factors
# 79                    Heart bypass surgery       both  Risk factors
# 98                       History of stroke       both  Risk factors
# 141                     Prior heart attack       both  Risk factors
#
#     seriousness     _merge
# 34       normal  left_only
# 37       normal  left_only
# 45       normal  left_only
# 46       normal  left_only
# 75       normal  left_only
# 79       normal  left_only
# 98       normal  left_only
# 141      normal  left_only

# %% [markdown]
# --------------

# %%
obj3 = df_options(data3_group_mm,data3_group_mf)
data3 = obj3.merged_data()
data3.head()
# Out:
#                           name                  common_name sex_filter  \
# 0  ACE inhibitor-induced cough  ACE inhibitor-induced cough       both
# 1    Abdominal aortic aneurysm    Abdominal aortic aneurysm       both
# 2  Abdominal aortic dissection  Abdominal aortic dissection       both
# 3  Abdominal pain, unspecified    Unspecific abdominal pain       both
# 4         Abducens nerve palsy            Sixth nerve palsy       both
#
#          categories prevalence                  acuteness severity  \
# 0        Cardiology  very_rare  acute_potentially_chronic     mild
# 1           Surgery  very_rare                    chronic   severe
# 2           Surgery  very_rare  acute_potentially_chronic   severe
# 3  Gastroenterology     common                      acute     mild
# 4     Ophthalmology  very_rare                    chronic     mild
#
#           triage_level     recommended_channel
# 0         consultation  audio_teleconsultation
# 1      consultation_24          personal_visit
# 2  emergency_ambulance          personal_visit
# 3            self_care   text_teleconsultation
# 4         consultation          personal_visit

# %%
obj3.uncomman_data().head()
# Out:
#                                                 name  \
# 82                               Aphthous stomatitis
# 91                                Atrophic vaginitis
# 93                                Atypical pneumonia
# 165                              Chronic tonsillitis
# 198  Degenerative disc disease of the cervical spine
#
#                                          common_name sex_filter  \
# 82                                      Canker sores       both
# 91                                 Atrophy of vagina     female
# 93                                Atypical pneumonia       both
# 165                              Chronic tonsillitis       both
# 198  Degenerative disc disease of the cervical spine       both
#
#               categories prevalence                   acuteness  severity  \
# 82             Dentistry  very_rare  chronic_with_exacerbations      mild
# 91            Gynecology  very_rare                     chronic      mild
# 93           Pulmonology       rare                       acute  moderate
# 165  Otorhinolaryngology  very_rare                     chronic  moderate
# 198            Neurology   moderate                     chronic      mild
#
#         triage_level recommended_channel     _merge
# 82      consultation      personal_visit  left_only
# 91      consultation      personal_visit  left_only
# 93   consultation_24      personal_visit  left_only
# 165     consultation      personal_visit  left_only
# 198     consultation      personal_visit  left_only

# %% [markdown]
# ---------

# %%
df_options.pattern(data3,'cold')
# Out:
# <style type="text/css">
# #T_7f69c_row0_col0, #T_7f69c_row0_col1, #T_7f69c_row1_col0, #T_7f69c_row1_col1, #T_7f69c_row2_col1 {
#   background-color: yellow;
# }
# #T_7f69c_row0_col2, #T_7f69c_row0_col3, #T_7f69c_row0_col4, #T_7f69c_row0_col5, #T_7f69c_row0_col6, #T_7f69c_row0_col7, #T_7f69c_row0_col8, #T_7f69c_row1_col2, #T_7f69c_row1_col3, #T_7f69c_row1_col4, #T_7f69c_row1_col5, #T_7f69c_row1_col6, #T_7f69c_row1_col7, #T_7f69c_row1_col8, #T_7f69c_row2_col0, #T_7f69c_row2_col2, #T_7f69c_row2_col3, #T_7f69c_row2_col4, #T_7f69c_row2_col5, #T_7f69c_row2_col6, #T_7f69c_row2_col7, #T_7f69c_row2_col8 {
#   background-color: ;
# }
# </style>
# <table id="T_7f69c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f69c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7f69c_level0_col1" class="col_heading level0 col1" >common_name</th>
#       <th id="T_7f69c_level0_col2" class="col_heading level0 col2" >sex_filter</th>
#       <th id="T_7f69c_level0_col3" class="col_heading level0 col3" >categories</th>
#       <th id="T_7f69c_level0_col4" class="col_heading level0 col4" >prevalence</th>
#       <th id="T_7f69c_level0_col5" class="col_heading level0 col5" >acuteness</th>
#       <th id="T_7f69c_level0_col6" class="col_heading level0 col6" >severity</th>
#       <th id="T_7f69c_level0_col7" class="col_heading level0 col7" >triage_level</th>
#       <th id="T_7f69c_level0_col8" class="col_heading level0 col8" >recommended_channel</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f69c_level0_row0" class="row_heading level0 row0" >173</th>
#       <td id="T_7f69c_row0_col0" class="data row0 col0" >Cold urticaria</td>
#       <td id="T_7f69c_row0_col1" class="data row0 col1" >Cold urticaria</td>
#       <td id="T_7f69c_row0_col2" class="data row0 col2" >both</td>
#       <td id="T_7f69c_row0_col3" class="data row0 col3" >Dermatology</td>
#       <td id="T_7f69c_row0_col4" class="data row0 col4" >rare</td>
#       <td id="T_7f69c_row0_col5" class="data row0 col5" >chronic_with_exacerbations</td>
#       <td id="T_7f69c_row0_col6" class="data row0 col6" >moderate</td>
#       <td id="T_7f69c_row0_col7" class="data row0 col7" >self_care</td>
#       <td id="T_7f69c_row0_col8" class="data row0 col8" >video_teleconsultation</td>
#     </tr>
#     <tr>
#       <th id="T_7f69c_level0_row1" class="row_heading level0 row1" >175</th>
#       <td id="T_7f69c_row1_col0" class="data row1 col0" >Common cold</td>
#       <td id="T_7f69c_row1_col1" class="data row1 col1" >Common cold</td>
#       <td id="T_7f69c_row1_col2" class="data row1 col2" >both</td>
#       <td id="T_7f69c_row1_col3" class="data row1 col3" >Infectiology</td>
#       <td id="T_7f69c_row1_col4" class="data row1 col4" >common</td>
#       <td id="T_7f69c_row1_col5" class="data row1 col5" >acute</td>
#       <td id="T_7f69c_row1_col6" class="data row1 col6" >mild</td>
#       <td id="T_7f69c_row1_col7" class="data row1 col7" >self_care</td>
#       <td id="T_7f69c_row1_col8" class="data row1 col8" >text_teleconsultation</td>
#     </tr>
#     <tr>
#       <th id="T_7f69c_level0_row2" class="row_heading level0 row2" >467</th>
#       <td id="T_7f69c_row2_col0" class="data row2 col0" >Oral herpes</td>
#       <td id="T_7f69c_row2_col1" class="data row2 col1" >Cold sore</td>
#       <td id="T_7f69c_row2_col2" class="data row2 col2" >both</td>
#       <td id="T_7f69c_row2_col3" class="data row2 col3" >Dermatology</td>
#       <td id="T_7f69c_row2_col4" class="data row2 col4" >moderate</td>
#       <td id="T_7f69c_row2_col5" class="data row2 col5" >acute_potentially_chronic</td>
#       <td id="T_7f69c_row2_col6" class="data row2 col6" >mild</td>
#       <td id="T_7f69c_row2_col7" class="data row2 col7" >self_care</td>
#       <td id="T_7f69c_row2_col8" class="data row2 col8" >video_teleconsultation</td>
#     </tr>
#   </tbody>
# </table>

# %%
data2_group_mf
# Out:
#                                 name                           common_name  \
# 0                 Abdominal guarding                    Abdominal guarding
# 1                     Abdominal mass                       Lump in stomach
# 2                     Abdominal pain  Abdominal pain, unspecified location
# 3                     Abdominal pain       Burning or gnawing stomach pain
# 4                     Abdominal pain                  Central stomach pain
# ...                              ...                                   ...
# 1358            Writing difficulties                  Writing difficulties
# 1359                     Xanthelasma         Yellowish deposits on eyelids
# 1360                        Xanthoma         Yellowish deposits under skin
# 1361      Yellow nail discolouration                          Yellow nails
# 1362  Yellow or green coloured stool                 Yellow or green stool
#
#            disease_specify1 disease_specify2 disease_specify3 sex_filter  \
# 0                       NaN              NaN              NaN       both
# 1                       NaN              NaN              NaN       both
# 2      unspecified location              NaN              NaN       both
# 3        burning or gnawing              NaN              NaN       both
# 4             periumbilical              NaN              NaN       both
# ...                     ...              ...              ...        ...
# 1358                    NaN              NaN              NaN       both
# 1359                    NaN              NaN              NaN       both
# 1360                    NaN              NaN              NaN       both
# 1361                    NaN              NaN              NaN       both
# 1362                    NaN              NaN              NaN       both
#
#                 category seriousness
# 0     Signs and symptoms   emergency
# 1     Signs and symptoms      normal
# 2     Signs and symptoms      normal
# 3     Signs and symptoms      normal
# 4     Signs and symptoms      normal
# ...                  ...         ...
# 1358  Signs and symptoms      normal
# 1359  Signs and symptoms      normal
# 1360  Signs and symptoms      normal
# 1361  Signs and symptoms      normal
# 1362  Signs and symptoms      normal
#
# [1363 rows x 8 columns]
